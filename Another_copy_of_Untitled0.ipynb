# %%
#1
#a=25
#b=30
#print(a+b)
#2

#a=25
#b=30
#print(a-b)
#3
#a=25
#b=30
#print(a/b)
#4
#a=25
#b=30
#print(a*b)
#5
#a=2
#for i in range(1,11):
  #print(2*i)
  #6
#n = int(input())

#a=0
#b=1

#for i in range(n):
    #print(a, end=" ")
    #c = a + b
    #a = b
    #b = c
#7
#a=2.5
#print(type(a))
#print(type(b))
#8
import math
print(math.pi)
print(math.cos(math.pi))
print(math.exp(10))
print(math.log(1000))
print(math.factorial(6))
# Out:
# 3.141592653589793
# -1.0
# 22026.465794806718
# 6.907755278982137
# 720
